# %% [markdown]
# Check GPU

# %%
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# Tesla T4, 15360 MiB, 15101 MiB

# %% [markdown]
# Installation

# %%
import sys
import torch
pyt_version_str=torch.__version__.split("+")[0].replace(".", "")
version_str="".join([
    f"py3{sys.version_info.minor}_cu",
    torch.version.cuda.replace(".",""),
    f"_pyt{pyt_version_str}"
])
# !pip install iopath
# !pip install fvcore
# !pip install --no-index --no-cache-dir pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/{version_str}/download.html
# Out:
# Collecting iopath
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from iopath) (4.66.5)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from iopath) (4.12.2)
# Collecting portalocker (from iopath)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: iopath
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31529 sha256=4ae730208c17b2c09b6d93f2f61e2f340665b73597049ddd81757ea68c877f06
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built iopath
# Installing collected packages: portalocker, iopath
# Successfully installed iopath-0.1.10 portalocker-2.10.1
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore) (1.26.4)
# Collecting yacs>=0.1.6 (from fvcore)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fvcore) (4.66.5)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore) (2.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from fvcore) (9.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore) (0.9.0)
# Requirement already satisfied: iopath>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from fvcore) (0.1.10)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from iopath>=0.1.7->fvcore) (4.12.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath>=0.1.7->fvcore) (2.10.1)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Building wheels for collected packages: fvcore
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61395 sha256=73b3c58aa7ec7740e0b9fd0493ef7ed22b547838eff1f9ac923e4ba4bcdc86b3
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
# Successfully built fvcore
# Installing collected packages: yacs, fvcore
# Successfully installed fvcore-0.1.5.post20221221 yacs-0.1.8
# Looking in links: https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/py310_cu121_pyt231/download.html
# Collecting pytorch3d
#   Downloading https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/py310_cu121_pyt231/pytorch3d-0.7.6-cp310-cp310-linux_x86_64.whl (20.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 140.3 MB/s eta 0:00:00
# Requirement already satisfied: fvcore in /usr/local/lib/python3.10/dist-packages (from pytorch3d) (0.1.5.post20221221)
# Requirement already satisfied: iopath in /usr/local/lib/python3.10/dist-packages (from pytorch3d) (0.1.10)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorch3d) (1.26.4)
# Requirement already satisfied: yacs>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorch3d) (0.1.8)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorch3d) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorch3d) (4.66.5)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorch3d) (2.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorch3d) (9.4.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from fvcore->pytorch3d) (0.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from iopath->pytorch3d) (4.12.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->pytorch3d) (2.10.1)
# Installing collected packages: pytorch3d
# Successfully installed pytorch3d-0.7.6

# %%
# install dependencies, about 5~10 min
# !pip install tensorboard==2.13.0 tensorboardX==2.6.1
# !pip install pyspy==0.1.1
# !pip install protobuf==4.25.4
# !pip install scipy
# !pip install kornia==0.5.0
# !pip install trimesh==3.22.0
# !pip install einops==0.6.1 torchshow==0.5.1
# !pip install imageio==2.31.1 imageio-ffmpeg==0.4.8
# !pip install scikit-learn==1.3.0 scikit-image==0.21.0
# !pip install av==10.0.0 lpips==0.1.4
# !pip install timm==0.9.2 librosa==0.9.2
# !pip install openmim==0.3.9
# !mim install mmcv # use mim to speed up installation for mmcv
# !pip install transformers==4.33.2
# !pip install pretrainedmodels==0.7.4
# !pip install ninja==1.11.1
# !pip install faiss-cpu==1.7.4
# !pip install praat-parselmouth==0.4.3 moviepy==1.0.3
# !pip install mediapipe
# !pip install --upgrade attr
# !pip install beartype==0.16.4 gateloop_transformer
# !pip install torchode==0.2.0 torchdiffeq==0.2.3
# !pip install hydra-core==1.3.2 pandas==2.1.3
# !pip install pytorch_lightning==2.1.2
# !pip install httpx==0.23.3
# !pip install gradio==4.16.0
# !pip install gdown
# !pip install pyloudnorm webrtcvad pyworld==0.2.1rc0 pypinyin==0.42.0
# !pip install PyMCubes
# Out:
# Collecting tensorboard==2.13.0
#   Downloading tensorboard-2.13.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorboardX==2.6.1
#   Downloading tensorboardX-2.6.1-py2.py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0) (2.27.0)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard==2.13.0)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0) (3.7)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0) (2.32.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0) (71.0.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0) (3.0.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.13.0) (0.44.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardX==2.6.1) (24.1)
# Collecting protobuf>=3.19.6 (from tensorboard==2.13.0)
#   Downloading protobuf-5.27.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.13.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.13.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard==2.13.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard==2.13.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.13.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.13.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.13.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard==2.13.0) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard==2.13.0) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.13.0) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard==2.13.0) (3.2.2)
# Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 50.2 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.1-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.3 MB/s eta 0:00:00
# Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Downloading protobuf-5.27.3-cp38-abi3-manylinux2014_x86_64.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.3/309.3 kB 21.9 MB/s eta 0:00:00
# Installing collected packages: protobuf, tensorboardX, google-auth-oauthlib, tensorboard
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires protobuf<5,>=3.20, but you have protobuf 5.27.3 which is incompatible.
# google-ai-generativelanguage 0.6.6 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.3 which is incompatible.
# google-cloud-bigquery-storage 2.25.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.3 which is incompatible.
# google-cloud-datastore 2.19.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.3 which is incompatible.
# google-cloud-firestore 2.16.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 5.27.3 which is incompatible.
# tensorflow 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.27.3 which is incompatible.
# tensorflow 2.17.0 requires tensorboard<2.18,>=2.17, but you have tensorboard 2.13.0 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 5.27.3 which is incompatible.
# Successfully installed google-auth-oauthlib-1.0.0 protobuf-5.27.3 tensorboard-2.13.0 tensorboardX-2.6.1
# Collecting pyspy==0.1.1
#   Downloading pyspy-0.1.1.tar.gz (1.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyspy
#   Building wheel for pyspy (setup.py) ... done
#   Created wheel for pyspy: filename=pyspy-0.1.1-py3-none-any.whl size=2031 sha256=3298b2e6f9b6e7138bfe8dbe4b8fd0cd0104ab67874203cf3c8a59ae5d65d868
#   Stored in directory: /root/.cache/pip/wheels/88/28/42/a86592a71ad8063361ee7bb19d3ccefd330c1bdd94cdaed663
# Successfully built pyspy
# Installing collected packages: pyspy
# Successfully installed pyspy-0.1.1
# Collecting protobuf==4.25.4
#   Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.27.3
#     Uninstalling protobuf-5.27.3:
#       Successfully uninstalled protobuf-5.27.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.0 requires tensorboard<2.18,>=2.17, but you have tensorboard 2.13.0 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.4 which is incompatible.
# Successfully installed protobuf-4.25.4
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.26.4)
# Collecting kornia==0.5.0
#   Downloading kornia-0.5.0-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from kornia==0.5.0) (1.26.4)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from kornia==0.5.0) (2.3.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->kornia==0.5.0) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->kornia==0.5.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->kornia==0.5.0) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->kornia==0.5.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->kornia==0.5.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->kornia==0.5.0) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->kornia==0.5.0) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->kornia==0.5.0)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->kornia==0.5.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->kornia==0.5.0) (1.3.0)
# Downloading kornia-0.5.0-py2.py3-none-any.whl (271 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.5/271.5 kB 7.1 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, kornia
# Successfully installed kornia-0.5.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105
# Collecting trimesh==3.22.0
#   Downloading trimesh-3.22.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from trimesh==3.22.0) (1.26.4)
# Downloading trimesh-3.22.0-py3-none-any.whl (681 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.5/681.5 kB 15.6 MB/s eta 0:00:00
# Installing collected packages: trimesh
# Successfully installed trimesh-3.22.0
# Collecting einops==0.6.1
#   Downloading einops-0.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting torchshow==0.5.1
#   Downloading torchshow-0.5.1-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchshow==0.5.1) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from torchshow==0.5.1) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->torchshow==0.5.1) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->torchshow==0.5.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->torchshow==0.5.1) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->torchshow==0.5.1) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->torchshow==0.5.1) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->torchshow==0.5.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->torchshow==0.5.1) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->torchshow==0.5.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->torchshow==0.5.1) (1.16.0)
# Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.9 MB/s eta 0:00:00
# Downloading torchshow-0.5.1-py3-none-any.whl (17 kB)
# Installing collected packages: einops, torchshow
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.0
#     Uninstalling einops-0.8.0:
#       Successfully uninstalled einops-0.8.0
# Successfully installed einops-0.6.1 torchshow-0.5.1
# Collecting imageio==2.31.1
#   Downloading imageio-2.31.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting imageio-ffmpeg==0.4.8
#   Downloading imageio_ffmpeg-0.4.8-py3-none-manylinux2010_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio==2.31.1) (1.26.4)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio==2.31.1) (9.4.0)
# Downloading imageio-2.31.1-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 7.7 MB/s eta 0:00:00
# Downloading imageio_ffmpeg-0.4.8-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 71.4 MB/s eta 0:00:00
# Installing collected packages: imageio-ffmpeg, imageio
#   Attempting uninstall: imageio-ffmpeg
#     Found existing installation: imageio-ffmpeg 0.5.1
#     Uninstalling imageio-ffmpeg-0.5.1:
#       Successfully uninstalled imageio-ffmpeg-0.5.1
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.34.2
#     Uninstalling imageio-2.34.2:
#       Successfully uninstalled imageio-2.34.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-image 0.23.2 requires imageio>=2.33, but you have imageio 2.31.1 which is incompatible.
# Successfully installed imageio-2.31.1 imageio-ffmpeg-0.4.8
# Collecting scikit-learn==1.3.0
#   Downloading scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scikit-image==0.21.0
#   Downloading scikit_image-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.0) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.0) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.0) (3.5.0)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.21.0) (3.3)
# Requirement already satisfied: pillow>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.21.0) (9.4.0)
# Requirement already satisfied: imageio>=2.27 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.21.0) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.21.0) (2024.8.10)
# Collecting PyWavelets>=1.1.1 (from scikit-image==0.21.0)
#   Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.21.0) (24.1)
# Requirement already satisfied: lazy_loader>=0.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.21.0) (0.4)
# Downloading scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 99.1 MB/s eta 0:00:00
# Downloading scikit_image-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.2 MB/s eta 0:00:00
# Downloading pywavelets-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 90.9 MB/s eta 0:00:00
# Installing collected packages: PyWavelets, scikit-learn, scikit-image
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.23.2
#     Uninstalling scikit-image-0.23.2:
#       Successfully uninstalled scikit-image-0.23.2
# Successfully installed PyWavelets-1.7.0 scikit-image-0.21.0 scikit-learn-1.3.0
# Collecting av==10.0.0
#   Downloading av-10.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Collecting lpips==0.1.4
#   Downloading lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (2.3.1+cu121)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (0.18.1+cu121)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (1.26.4)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (1.13.1)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.10/dist-packages (from lpips==0.1.4) (4.66.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=0.4.0->lpips==0.1.4) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=0.4.0->lpips==0.1.4) (12.6.20)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.2.1->lpips==0.1.4) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=0.4.0->lpips==0.1.4) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=0.4.0->lpips==0.1.4) (1.3.0)
# Downloading av-10.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 22.1 MB/s eta 0:00:00
# Downloading lpips-0.1.4-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: av, lpips
# Successfully installed av-10.0.0 lpips-0.1.4
# Collecting timm==0.9.2
#   Downloading timm-0.9.2-py3-none-any.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 3.0 MB/s eta 0:00:00
# Collecting librosa==0.9.2
#   Downloading librosa-0.9.2-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2) (2.3.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2) (0.18.1+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2) (6.0.2)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2) (0.23.5)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm==0.9.2) (0.4.4)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (3.0.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (1.4.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (4.4.2)
# Collecting resampy>=0.2.2 (from librosa==0.9.2)
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (0.60.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (24.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa==0.9.2) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.9.2) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.9.2) (2.32.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->librosa==0.9.2) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.10.2->librosa==0.9.2) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->timm==0.9.2) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7->timm==0.9.2) (12.6.20)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm==0.9.2) (4.66.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.9.2) (9.4.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.2) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->timm==0.9.2) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7->timm==0.9.2) (1.3.0)
# Downloading timm-0.9.2-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 45.9 MB/s eta 0:00:00
# Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 17.6 MB/s eta 0:00:00
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 85.1 MB/s eta 0:00:00
# Installing collected packages: resampy, librosa, timm
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.2.post1
#     Uninstalling librosa-0.10.2.post1:
#       Successfully uninstalled librosa-0.10.2.post1
# Successfully installed librosa-0.9.2 resampy-0.4.3 timm-0.9.2
# Collecting openmim==0.3.9
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from openmim==0.3.9) (8.1.7)
# Collecting colorama (from openmim==0.3.9)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting model-index (from openmim==0.3.9)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim==0.3.9)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from openmim==0.3.9) (2.1.4)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim==0.3.9) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmim==0.3.9) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openmim==0.3.9) (13.7.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim==0.3.9) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from model-index->openmim==0.3.9) (6.0.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from model-index->openmim==0.3.9) (3.7)
# Collecting ordered-set (from model-index->openmim==0.3.9)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pycryptodome (from opendatalab->openmim==0.3.9)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim==0.3.9) (4.66.5)
# Collecting openxlab (from opendatalab->openmim==0.3.9)
#   Downloading openxlab-0.1.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->openmim==0.3.9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmim==0.3.9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmim==0.3.9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmim==0.3.9) (2024.7.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim==0.3.9) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim==0.3.9) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim==0.3.9) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim==0.3.9) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim==0.3.9) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim==0.3.9) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->openmim==0.3.9) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->openmim==0.3.9) (1.16.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim==0.3.9)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim==0.3.9)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging~=24.0 in /usr/local/lib/python3.10/dist-packages (from openxlab->opendatalab->openmim==0.3.9) (24.1)
# Collecting pytz>=2020.1 (from pandas->openmim==0.3.9)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim==0.3.9)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim==0.3.9)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim==0.3.9)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim==0.3.9)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 4.7 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1 (from requests->openmim==0.3.9)
#   Downloading urllib3-1.26.19-py2.py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.0 MB/s eta 0:00:00
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim==0.3.9)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim==0.3.9)
#   Downloading aliyun_python_sdk_kms-2.16.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim==0.3.9)
#   Downloading aliyun-python-sdk-core-2.15.1.tar.gz (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.1/443.1 kB 28.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim==0.3.9)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim==0.3.9) (43.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim==0.3.9) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim==0.3.9) (2.22)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 4.5 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading openxlab-0.1.1-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.6/308.6 kB 21.3 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.5 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 16.6 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 31.6 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 6.4 MB/s eta 0:00:00
# Downloading urllib3-1.26.19-py2.py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 kB 12.5 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 59.7 MB/s eta 0:00:00
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 42.8 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.4-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 7.3 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112372 sha256=ab9428502d305228c27589c32e147ebab873039944621549251c6423e621bc36
#   Stored in directory: /root/.cache/pip/wheels/87/04/7b/7e61b8157fdf211c5131375240d0d86ca82e2a88ead9672c88
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.15.1-py3-none-any.whl size=535322 sha256=9d6956316ec96aca4b59f564918474de1cc4f439bd62f28424052ecfeebd5631
#   Stored in directory: /root/.cache/pip/wheels/69/4b/8e/0a28e00f4cf43b273c18cce083804738d41013e017da922ce4
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31404 sha256=1ff2a2234bcbc4fda447246fc92d752ec4e72d7b1770b83787cefcbb8c774977
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: pytz, crcmod, urllib3, tqdm, setuptools, pycryptodome, ordered-set, jmespath, filelock, colorama, rich, requests, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.5
#     Uninstalling tqdm-4.66.5:
#       Successfully uninstalled tqdm-4.66.5
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 71.0.4
#     Uninstalling setuptools-71.0.4:
#       Successfully uninstalled setuptools-71.0.4
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.15.4
#     Uninstalling filelock-3.15.4:
#       Successfully uninstalled filelock-3.15.4
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.28.2 which is incompatible.
# tensorflow 2.17.0 requires tensorboard<2.18,>=2.17, but you have tensorboard 2.13.0 which is incompatible.
# yfinance 0.2.41 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.15.1 aliyun-python-sdk-kms-2.16.4 colorama-0.4.6 crcmod-1.7 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.1 ordered-set-4.1.0 oss2-2.17.0 pycryptodome-3.20.0 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2 urllib3-1.26.19
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.3.0/index.html
# Collecting mmcv
#   Downloading https://download.openmmlab.com/mmcv/dist/cu121/torch2.3.0/mmcv-2.2.0-cp310-cp310-manylinux1_x86_64.whl (97.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 MB 5.4 MB/s eta 0:00:00
# Collecting addict (from mmcv)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting mmengine>=0.3.0 (from mmcv)
#   Downloading mmengine-0.10.4-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmcv) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcv) (24.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv) (9.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv) (6.0.2)
# Collecting yapf (from mmcv)
#   Downloading yapf-0.40.2-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmcv) (4.10.0.84)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv) (3.7.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv) (2.4.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv) (8.4.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv) (4.2.2)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv) (3.20.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv) (1.16.0)
# Downloading mmengine-0.10.4-py3-none-any.whl (451 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 16.4 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.40.2-py3-none-any.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 22.1 MB/s eta 0:00:00
# Installing collected packages: addict, yapf, mmengine, mmcv
# Successfully installed addict-2.4.0 mmcv-2.2.0 mmengine-0.10.4 yapf-0.40.2
# Collecting transformers==4.33.2
#   Downloading transformers-4.33.2-py3-none-any.whl.metadata (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.2) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.2) (0.23.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.33.2) (1.26.4)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 4.2 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: rfc3986, h11, httpcore, httpx
# Successfully installed h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 rfc3986-1.5.0
# Collecting gradio==4.16.0
#   Downloading gradio-4.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio==4.16.0)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (4.2.2)
# Collecting fastapi (from gradio==4.16.0)
#   Downloading fastapi-0.112.2-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio==4.16.0)
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==0.8.1 (from gradio==4.16.0)
#   Downloading gradio_client-0.8.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (0.23.3)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (0.23.5)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (6.4.3)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (1.26.4)
# Collecting orjson~=3.0 (from gradio==4.16.0)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (2.1.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (2.8.2)
# Collecting pydub (from gradio==4.16.0)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart (from gradio==4.16.0)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (6.0.2)
# Collecting ruff>=0.1.7 (from gradio==4.16.0)
#   Downloading ruff-0.6.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio==4.16.0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio==4.16.0)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio==4.16.0) (0.12.4)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.16.0) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio==4.16.0)
#   Downloading uvicorn-0.30.6-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.8.1->gradio==4.16.0) (2024.6.1)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.8.1->gradio==4.16.0)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.16.0) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.16.0) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.16.0) (0.12.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.16.0) (3.14.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.16.0) (2.28.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.16.0) (4.65.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.16.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.16.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.16.0) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.16.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.16.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.16.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.16.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.16.0) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.16.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.16.0) (2.20.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio==4.16.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio==4.16.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio==4.16.0) (13.4.2)
# WARNING: typer 0.12.4 does not provide the extra 'all'
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==4.16.0) (0.14.0)
# Collecting starlette<0.39.0,>=0.37.2 (from fastapi->gradio==4.16.0)
#   Downloading starlette-0.38.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==4.16.0) (2024.7.4)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==4.16.0) (0.16.3)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from rfc3986[idna2008]<2,>=1.3->httpx->gradio==4.16.0) (1.5.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==4.16.0) (1.3.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio==4.16.0) (3.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.16.0) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.16.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.16.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.16.0) (0.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.16.0) (1.16.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from rfc3986[idna2008]<2,>=1.3->httpx->gradio==4.16.0) (3.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio==4.16.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio==4.16.0) (2.16.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->gradio==4.16.0) (3.3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->gradio==4.16.0) (1.26.19)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.17.0,>=0.15.0->httpx->gradio==4.16.0) (1.2.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio==4.16.0) (0.1.2)
# Downloading gradio-4.16.0-py3-none-any.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 88.2 MB/s eta 0:00:00
# Downloading gradio_client-0.8.1-py3-none-any.whl (305 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 24.1 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 12.5 MB/s eta 0:00:00
# Downloading ruff-0.6.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 47.2 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading uvicorn-0.30.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.7 MB/s eta 0:00:00
# Downloading fastapi-0.112.2-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 8.7 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading starlette-0.38.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.1 MB/s eta 0:00:00
# Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 12.2 MB/s eta 0:00:00
# Installing collected packages: pydub, websockets, uvicorn, tomlkit, semantic-version, ruff, python-multipart, orjson, ffmpy, aiofiles, starlette, fastapi, gradio-client, gradio
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.13.2
#     Uninstalling tomlkit-0.13.2:
#       Successfully uninstalled tomlkit-0.13.2
# Successfully installed aiofiles-23.2.1 fastapi-0.112.2 ffmpy-0.4.0 gradio-4.16.0 gradio-client-0.8.1 orjson-3.10.7 pydub-0.25.1 python-multipart-0.0.9 ruff-0.6.2 semantic-version-2.10.0 starlette-0.38.2 tomlkit-0.12.0 uvicorn-0.30.6 websockets-11.0.3
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.14.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.28.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.65.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.7.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Collecting pyloudnorm
#   Downloading pyloudnorm-0.1.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting webrtcvad
#   Downloading webrtcvad-2.0.10.tar.gz (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyworld==0.2.1rc0
#   Downloading pyworld-0.2.1rc0.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pypinyin==0.42.0
#   Downloading pypinyin-0.42.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyworld==0.2.1rc0) (1.26.4)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from pyworld==0.2.1rc0) (3.0.11)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from pyloudnorm) (1.13.1)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from pyloudnorm) (1.0.0)
# Downloading pypinyin-0.42.0-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.4 MB/s eta 0:00:00
# Downloading pyloudnorm-0.1.1-py3-none-any.whl (9.6 kB)
# Building wheels for collected packages: pyworld, webrtcvad
#   Building wheel for pyworld (setup.py) ... done
#   Created wheel for pyworld: filename=pyworld-0.2.1rc0-cp310-cp310-linux_x86_64.whl size=846353 sha256=5630a1c2ea9b59685f7e4d50a0349324885917d5eae8004961ddf6099d4cdb66
#   Stored in directory: /root/.cache/pip/wheels/59/a6/fe/029fe18ac9cedf52a5535bd8efb4503c8fac4945b376168ff5
#   Building wheel for webrtcvad (setup.py) ... done
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp310-cp310-linux_x86_64.whl size=73486 sha256=41262b7af172fe3e92e0dbaf763fcd9692fe42aae5471f14b373801206f25620
#   Stored in directory: /root/.cache/pip/wheels/2a/2b/84/ac7bacfe8c68a87c1ee3dd3c66818a54c71599abf308e8eb35
# Successfully built pyworld webrtcvad
# Installing collected packages: webrtcvad, pyworld, pypinyin, pyloudnorm
# Successfully installed pyloudnorm-0.1.1 pypinyin-0.42.0 pyworld-0.2.1rc0 webrtcvad-2.0.10
# Collecting PyMCubes
#   Downloading PyMCubes-0.1.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (868 bytes)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from PyMCubes) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from PyMCubes) (1.13.1)
# Downloading PyMCubes-0.1.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.4/318.4 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: PyMCubes
# Successfully installed PyMCubes-0.1.6

# %%
# RESTART kernel to make sure runtime is correct if you meet runtime errors
# import os
# os.kill(os.getpid(), 9)

# %% [markdown]
# Clone code and download checkpoints

# %%
# clone GeneFacePlusPlus repo from github
# !git clone https://github.com/yerfor/GeneFacePlusPlus
# %cd GeneFacePlusPlus
# Out:
# Cloning into 'GeneFacePlusPlus'...
# remote: Enumerating objects: 520, done.
# remote: Counting objects: 100% (208/208), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 520 (delta 121), reused 114 (delta 114), pack-reused 312 (from 1)
# Receiving objects: 100% (520/520), 37.36 MiB | 17.35 MiB/s, done.
# Resolving deltas: 100% (169/169), done.
# /content/GeneFacePlusPlus

# %%
# replacing all 'c++14' with 'c++17' for compatible in CUDA 12
# special thanks to @yyheart in https://github.com/yerfor/GeneFacePlusPlus/issues/12
import glob
all_files = glob.glob("modules/radnerfs/*.py") + glob.glob("modules/radnerfs/*/*.py") + glob.glob("modules/radnerfs/*/*/*.py") + glob.glob("modules/radnerfs/*/*/*/*.py")
for file in all_files:
  with open(file) as f:
    lines = f.readlines()
    lines = [line.replace('-std=c++14', '-std=c++17') for line in lines]
    lines = [line.replace('\'-use_fast_math\'', '') for line in lines]
    if 'backend' in file:
      print(lines)
  with open(file, 'w') as f:
    f.writelines(lines)

# build extensions, it takes a long time (about 10 min)
# !bash docs/prepare_env/install_ext.sh
# Out:
# ['import os\n', 'from torch.utils.cpp_extension import load\n', '\n', '_src_path = os.path.dirname(os.path.abspath(__file__))\n', '\n', 'nvcc_flags = [\n', "    '-O3', '-std=c++17',\n", "    '-U__CUDA_NO_HALF_OPERATORS__', '-U__CUDA_NO_HALF_CONVERSIONS__', '-U__CUDA_NO_HALF2_OPERATORS__',\n", ']\n', '\n', 'if os.name == "posix":\n', "    c_flags = ['-O3', '-std=c++17']\n", 'elif os.name == "nt":\n', "    c_flags = ['/O2', '/std:c++17']\n", '\n', '    # find cl.exe\n', '    def find_cl_path():\n', '        import glob\n', '        for edition in ["Enterprise", "Professional", "BuildTools", "Community"]:\n', '            paths = sorted(glob.glob(r"C:\\\\Program Files (x86)\\\\Microsoft Visual Studio\\\\*\\\\%s\\\\VC\\\\Tools\\\\MSVC\\\\*\\\\bin\\\\Hostx64\\\\x64" % edition), reverse=True)\n', '            if paths:\n', '                return paths[0]\n', '\n', '    # If cl.exe is not on path, try to find it.\n', '    if os.system("where cl.exe >nul 2>nul") != 0:\n', '        cl_path = find_cl_path()\n', '        if cl_path is None:\n', '            raise RuntimeError("Could not locate a supported Microsoft Visual C++ installation")\n', '        os.environ["PATH"] += ";" + cl_path\n', '\n', "_backend = load(name='_raymarching_face',\n", '                extra_cflags=c_flags,\n', '                extra_cuda_cflags=nvcc_flags,\n', "                sources=[os.path.join(_src_path, 'src', f) for f in [\n", "                    'raymarching.cu',\n", "                    'bindings.cpp',\n", '                ]],\n', '                )\n', '\n', "__all__ = ['_backend']"]
# ['import os\n', 'from torch.utils.cpp_extension import load\n', '\n', '_src_path = os.path.dirname(os.path.abspath(__file__))\n', '\n', 'nvcc_flags = [\n', "    '-O3', '-std=c++17',\n", "    '-U__CUDA_NO_HALF_OPERATORS__', '-U__CUDA_NO_HALF_CONVERSIONS__', '-U__CUDA_NO_HALF2_OPERATORS__',\n", ']\n', '\n', 'if os.name == "posix":\n', "    c_flags = ['-O3', '-std=c++17']\n", 'elif os.name == "nt":\n', "    c_flags = ['/O2', '/std:c++17']\n", '\n', '    # find cl.exe\n', '    def find_cl_path():\n', '        import glob\n', '        for edition in ["Enterprise", "Professional", "BuildTools", "Community"]:\n', '            paths = sorted(glob.glob(r"C:\\\\Program Files (x86)\\\\Microsoft Visual Studio\\\\*\\\\%s\\\\VC\\\\Tools\\\\MSVC\\\\*\\\\bin\\\\Hostx64\\\\x64" % edition), reverse=True)\n', '            if paths:\n', '                return paths[0]\n', '\n', '    # If cl.exe is not on path, try to find it.\n', '    if os.system("where cl.exe >nul 2>nul") != 0:\n', '        cl_path = find_cl_path()\n', '        if cl_path is None:\n', '            raise RuntimeError("Could not locate a supported Microsoft Visual C++ installation")\n', '        os.environ["PATH"] += ";" + cl_path\n', '\n', "_backend = load(name='_sh_encoder',\n", '                extra_cflags=c_flags,\n', '                extra_cuda_cflags=nvcc_flags,\n', "                sources=[os.path.join(_src_path, 'src', f) for f in [\n", "                    'shencoder.cu',\n", "                    'bindings.cpp',\n", '                ]],\n', '                )\n', '\n', "__all__ = ['_backend']"]
# ['import os\n', 'from torch.utils.cpp_extension import load\n', '\n', '_src_path = os.path.dirname(os.path.abspath(__file__))\n', '\n', 'nvcc_flags = [\n', "    '-O3', '-std=c++17',\n", "    '-U__CUDA_NO_HALF_OPERATORS__', '-U__CUDA_NO_HALF_CONVERSIONS__', '-U__CUDA_NO_HALF2_OPERATORS__',\n", ']\n', '\n', 'if os.name == "posix":\n', "    c_flags = ['-O3', '-std=c++17']\n", 'elif os.name == "nt":\n', "    c_flags = ['/O2', '/std:c++17']\n", '\n', '    # find cl.exe\n', '    def find_cl_path():\n', '        import glob\n', '        for edition in ["Enterprise", "Professional", "BuildTools", "Community"]:\n', '            paths = sorted(glob.glob(r"C:\\\\Program Files (x86)\\\\Microsoft Visual Studio\\\\*\\\\%s\\\\VC\\\\Tools\\\\MSVC\\\\*\\\\bin\\\\Hostx64\\\\x64" % edition), reverse=True)\n', '            if paths:\n', '                return paths[0]\n', '\n', '    # If cl.exe is not on path, try to find it.\n', '    if os.system("where cl.exe >nul 2>nul") != 0:\n', '        cl_path = find_cl_path()\n', '        if cl_path is None:\n', '            raise RuntimeError("Could not locate a supported Microsoft Visual C++ installation")\n', '        os.environ["PATH"] += ";" + cl_path\n', '\n', "_backend = load(name='_grid_encoder',\n", '                extra_cflags=c_flags,\n', '                extra_cuda_cflags=nvcc_flags,\n', "                sources=[os.path.join(_src_path, 'src', f) for f in [\n", "                    'gridencoder.cu',\n", "                    'bindings.cpp',\n", '                ]],\n', '                )\n', '\n', "__all__ = ['_backend']"]
# ['import os\n', 'from torch.utils.cpp_extension import load\n', '\n', '_src_path = os.path.dirname(os.path.abspath(__file__))\n', '\n', 'nvcc_flags = [\n', "    '-O3', '-std=c++17',\n", "    '-U__CUDA_NO_HALF_OPERATORS__', '-U__CUDA_NO_HALF_CONVERSIONS__', '-U__CUDA_NO_HALF2_OPERATORS__',\n", '    \n', ']\n', '\n', 'if os.name == "posix":\n', "    c_flags = ['-O3', '-std=c++17']\n", 'elif os.name == "nt":\n', "    c_flags = ['/O2', '/std:c++17']\n", '\n', '    # find cl.exe\n', '    def find_cl_path():\n', '        import glob\n', '        for edition in ["Enterprise", "Professional", "BuildTools", "Community"]:\n', '            paths = sorted(glob.glob(r"C:\\\\Program Files (x86)\\\\Microsoft Visual Studio\\\\*\\\\%s\\\\VC\\\\Tools\\\\MSVC\\\\*\\\\bin\\\\Hostx64\\\\x64" % edition), reverse=True)\n', '            if paths:\n', '                return paths[0]\n', '\n', '    # If cl.exe is not on path, try to find it.\n', '    if os.system("where cl.exe >nul 2>nul") != 0:\n', '        cl_path = find_cl_path()\n', '        if cl_path is None:\n', '            raise RuntimeError("Could not locate a supported Microsoft Visual C++ installation")\n', '        os.environ["PATH"] += ";" + cl_path\n', '\n', "_backend = load(name='_freqencoder',\n", '                extra_cflags=c_flags,\n', '                extra_cuda_cflags=nvcc_flags,\n', "                sources=[os.path.join(_src_path, 'src', f) for f in [\n", "                    'freqencoder.cu',\n", "                    'bindings.cpp',\n", '                ]],\n', '                )\n', '\n', "__all__ = ['_backend']"]
# Using pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Processing ./modules/radnerfs/encoders/freqencoder
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-vh7qsz9j/freqencoder.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-vh7qsz9j/freqencoder.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-vh7qsz9j/freqencoder.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: freqencoder
#   Running command python setup.py bdist_wheel
#   running bdist_wheel
#   running build
#   running build_ext
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:418: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#     warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:428: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.2
#     warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/src
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1967: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
#   If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#     warnings.warn(
#   Emitting ninja build file /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/build.ninja...
#   Compiling objects...
#   Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
#   [1/2] c++ -MMD -MF /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/src/bindings.o.d -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/src/bindings.cpp -o /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/src/bindings.o -O3 -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_freqencoder -D_GLIBCXX_USE_CXX11_ABI=0
#   [2/2] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/src/freqencoder.o.d -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/src/freqencoder.cu -o /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/src/freqencoder.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -O3 -std=c++17 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_freqencoder -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=compute_75 -gencode=arch=compute_75,code=sm_75
#   creating build/lib.linux-x86_64-3.10
#   x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/src/bindings.o /content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/freqencoder/src/freqencoder.o -L/usr/local/lib/python3.10/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-3.10/_freqencoder.cpython-310-x86_64-linux-gnu.so
#   /usr/local/lib/python3.10/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   copying build/lib.linux-x86_64-3.10/_freqencoder.cpython-310-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/wheel
#   running install_egg_info
#   running egg_info
#   creating freqencoder.egg-info
#   writing manifest file 'freqencoder.egg-info/SOURCES.txt'
#   writing manifest file 'freqencoder.egg-info/SOURCES.txt'
#   Copying freqencoder.egg-info to build/bdist.linux-x86_64/wheel/freqencoder-0.0.0-py3.10.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/freqencoder-0.0.0.dist-info/WHEEL
#   creating '/tmp/pip-wheel-75zasxhg/freqencoder-0.0.0-cp310-cp310-linux_x86_64.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding '_freqencoder.cpython-310-x86_64-linux-gnu.so'
#   adding 'freqencoder-0.0.0.dist-info/METADATA'
#   adding 'freqencoder-0.0.0.dist-info/WHEEL'
#   adding 'freqencoder-0.0.0.dist-info/top_level.txt'
#   adding 'freqencoder-0.0.0.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for freqencoder (setup.py) ... done
#   Created wheel for freqencoder: filename=freqencoder-0.0.0-cp310-cp310-linux_x86_64.whl size=2496006 sha256=510c41925593cb84697b6adc2405f241f79d690a8e19bdd18839a3fb49ea834d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q7g1dbm3/wheels/b5/76/81/d1f1e8b3ee64e01ee56f3e32dd4c033964923b5e3671c4a6e2
# Successfully built freqencoder
# Installing collected packages: freqencoder
# Successfully installed freqencoder-0.0.0
# Using pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Processing ./modules/radnerfs/encoders/shencoder
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-w59_383e/shencoder.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-w59_383e/shencoder.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-w59_383e/shencoder.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: shencoder
#   Running command python setup.py bdist_wheel
#   running bdist_wheel
#   running build
#   running build_ext
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:418: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#     warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:428: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.2
#     warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/src
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1967: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
#   If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#     warnings.warn(
#   Emitting ninja build file /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/build.ninja...
#   Compiling objects...
#   Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
#   [1/2] c++ -MMD -MF /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/src/bindings.o.d -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/src/bindings.cpp -o /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/src/bindings.o -O3 -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_shencoder -D_GLIBCXX_USE_CXX11_ABI=0
#   [2/2] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/src/shencoder.o.d -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/src/shencoder.cu -o /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/src/shencoder.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -O3 -std=c++17 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_shencoder -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=compute_75 -gencode=arch=compute_75,code=sm_75
#   creating build/lib.linux-x86_64-3.10
#   x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/src/bindings.o /content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/shencoder/src/shencoder.o -L/usr/local/lib/python3.10/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-3.10/_shencoder.cpython-310-x86_64-linux-gnu.so
#   /usr/local/lib/python3.10/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   copying build/lib.linux-x86_64-3.10/_shencoder.cpython-310-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/wheel
#   running install_egg_info
#   running egg_info
#   creating shencoder.egg-info
#   writing manifest file 'shencoder.egg-info/SOURCES.txt'
#   writing manifest file 'shencoder.egg-info/SOURCES.txt'
#   Copying shencoder.egg-info to build/bdist.linux-x86_64/wheel/shencoder-0.0.0-py3.10.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/shencoder-0.0.0.dist-info/WHEEL
#   creating '/tmp/pip-wheel-4_487kw_/shencoder-0.0.0-cp310-cp310-linux_x86_64.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding '_shencoder.cpython-310-x86_64-linux-gnu.so'
#   adding 'shencoder-0.0.0.dist-info/METADATA'
#   adding 'shencoder-0.0.0.dist-info/WHEEL'
#   adding 'shencoder-0.0.0.dist-info/top_level.txt'
#   adding 'shencoder-0.0.0.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for shencoder (setup.py) ... done
#   Created wheel for shencoder: filename=shencoder-0.0.0-cp310-cp310-linux_x86_64.whl size=2577370 sha256=7e8d62cd4acd65f45f908129e092006069e89e3a1a707d79ff0c457ee5e66787
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eaxphyh4/wheels/5c/a1/73/ed6f720a33d16aaeaec4a70030807d52bb99570c3b6b0f6d74
# Successfully built shencoder
# Installing collected packages: shencoder
# Successfully installed shencoder-0.0.0
# Using pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Processing ./modules/radnerfs/encoders/gridencoder
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-12kh3xp3/gridencoder.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-12kh3xp3/gridencoder.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-12kh3xp3/gridencoder.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: gridencoder
#   Running command python setup.py bdist_wheel
#   running bdist_wheel
#   running build
#   running build_ext
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:418: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#     warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:428: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.2
#     warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder
#   creating /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/src
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1967: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
#   If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#     warnings.warn(
#   Emitting ninja build file /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/build.ninja...
#   Compiling objects...
#   Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
#   [1/2] c++ -MMD -MF /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/src/bindings.o.d -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/src/bindings.cpp -o /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/src/bindings.o -O3 -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_gridencoder -D_GLIBCXX_USE_CXX11_ABI=0
#   [2/2] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/src/gridencoder.o.d -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/src/gridencoder.cu -o /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/src/gridencoder.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -O3 -std=c++17 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_gridencoder -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=compute_75 -gencode=arch=compute_75,code=sm_75
#   creating build/lib.linux-x86_64-3.10
#   x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/src/bindings.o /content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/encoders/gridencoder/src/gridencoder.o -L/usr/local/lib/python3.10/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-3.10/_gridencoder.cpython-310-x86_64-linux-gnu.so
#   /usr/local/lib/python3.10/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   copying build/lib.linux-x86_64-3.10/_gridencoder.cpython-310-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/wheel
#   running install_egg_info
#   running egg_info
#   creating gridencoder.egg-info
#   writing manifest file 'gridencoder.egg-info/SOURCES.txt'
#   writing manifest file 'gridencoder.egg-info/SOURCES.txt'
#   Copying gridencoder.egg-info to build/bdist.linux-x86_64/wheel/gridencoder-0.0.0-py3.10.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/gridencoder-0.0.0.dist-info/WHEEL
#   creating '/tmp/pip-wheel-2k6cp2sc/gridencoder-0.0.0-cp310-cp310-linux_x86_64.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding '_gridencoder.cpython-310-x86_64-linux-gnu.so'
#   adding 'gridencoder-0.0.0.dist-info/METADATA'
#   adding 'gridencoder-0.0.0.dist-info/WHEEL'
#   adding 'gridencoder-0.0.0.dist-info/top_level.txt'
#   adding 'gridencoder-0.0.0.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for gridencoder (setup.py) ... done
#   Created wheel for gridencoder: filename=gridencoder-0.0.0-cp310-cp310-linux_x86_64.whl size=5317808 sha256=73d1ef550ac1a97a3db70f4b6ac9684c3fe8129f7bfab23addc3d78323a01d58
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qw84vs4y/wheels/a7/37/9a/bd4989450c60cc0c7d178d7e0ec4050bf3931cce4926bcbd91
# Successfully built gridencoder
# Installing collected packages: gridencoder
# Successfully installed gridencoder-0.0.0
# Using pip 24.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Processing ./modules/radnerfs/raymarching
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-1cgl2kh7/raymarching_face.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-1cgl2kh7/raymarching_face.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-1cgl2kh7/raymarching_face.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: raymarching-face
#   Running command python setup.py bdist_wheel
#   running bdist_wheel
#   running build
#   running build_ext
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:418: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#     warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:428: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.2
#     warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
#   creating /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build
#   creating /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10
#   creating /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content
#   creating /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus
#   creating /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules
#   creating /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs
#   creating /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/raymarching
#   creating /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/raymarching/src
#   /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1967: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
#   If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#     warnings.warn(
#   Emitting ninja build file /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/build.ninja...
#   Compiling objects...
#   Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
#   [1/2] c++ -MMD -MF /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/bindings.o.d -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/bindings.cpp -o /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/bindings.o -O3 -std=c++17 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_raymarching_face -D_GLIBCXX_USE_CXX11_ABI=0
#   [2/2] /usr/local/cuda/bin/nvcc --generate-dependencies-with-compile --dependency-output /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/raymarching.o.d -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c -c /content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/raymarching.cu -o /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/raymarching.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -O3 -std=c++17 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=_raymarching_face -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=compute_75 -gencode=arch=compute_75,code=sm_75
#   /content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/raymarching.cu(181): warning #177-D: variable "rdx" was declared but never referenced
#         const float rdx = 1 / dx, rdy = 1 / dy, rdz = 1 / dz;
#                     ^
#
#   Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
#   /content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/raymarching.cu(181): warning #177-D: variable "rdy" was declared but never referenced
#         const float rdx = 1 / dx, rdy = 1 / dy, rdz = 1 / dz;
#                                   ^
#
#   /content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/raymarching.cu(181): warning #177-D: variable "rdz" was declared but never referenced
#         const float rdx = 1 / dx, rdy = 1 / dy, rdz = 1 / dz;
#                                                 ^
#
#   /content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/raymarching.cu(553): warning #177-D: variable "index" was declared but never referenced
#         uint32_t index = rays[n * 3];
#                  ^
#
#   creating build/lib.linux-x86_64-3.10
#   x86_64-linux-gnu-g++ -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/bindings.o /content/GeneFacePlusPlus/modules/radnerfs/raymarching/build/temp.linux-x86_64-3.10/content/GeneFacePlusPlus/modules/radnerfs/raymarching/src/raymarching.o -L/usr/local/lib/python3.10/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-3.10/_raymarching_face.cpython-310-x86_64-linux-gnu.so
#   /usr/local/lib/python3.10/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   copying build/lib.linux-x86_64-3.10/_raymarching_face.cpython-310-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/wheel
#   running install_egg_info
#   running egg_info
#   creating raymarching_face.egg-info
#   writing manifest file 'raymarching_face.egg-info/SOURCES.txt'
#   writing manifest file 'raymarching_face.egg-info/SOURCES.txt'
#   Copying raymarching_face.egg-info to build/bdist.linux-x86_64/wheel/raymarching_face-0.0.0-py3.10.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/raymarching_face-0.0.0.dist-info/WHEEL
#   creating '/tmp/pip-wheel-gqtfuqun/raymarching_face-0.0.0-cp310-cp310-linux_x86_64.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
#   adding '_raymarching_face.cpython-310-x86_64-linux-gnu.so'
#   adding 'raymarching_face-0.0.0.dist-info/METADATA'
#   adding 'raymarching_face-0.0.0.dist-info/WHEEL'
#   adding 'raymarching_face-0.0.0.dist-info/top_level.txt'
#   adding 'raymarching_face-0.0.0.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Building wheel for raymarching-face (setup.py) ... done
#   Created wheel for raymarching-face: filename=raymarching_face-0.0.0-cp310-cp310-linux_x86_64.whl size=2817374 sha256=3e06c05032ae5b12afbc76b9fa2358c40f48c419a68621d9fb78c4cf0c7ec025
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kh08zwph/wheels/15/37/7a/1fb2c71e6869e3816635167b29d849118a88e35fa002f6587d
# Successfully built raymarching-face
# Installing collected packages: raymarching-face
# Successfully installed raymarching-face-0.0.0

# %%
# download pretrained ckpts & third-party ckpts from google drive, about 1 min

# %mkdir -p data/binary/videos/May
# %cd data/binary/videos/May
# !gdown https://drive.google.com/uc?id=16fNJz5MbOMqHYHxcK_nPP4EPBXWjugR0
# %cd ../../../..

# %cd deep_3drecon/BFM
# !gdown https://drive.google.com/uc?id=1SPM3IHsyNAaVMwqZZGV6QVaV7I2Hly0v
# !gdown https://drive.google.com/uc?id=1MSldX9UChKEb3AXLVTPzZQcsbGD4VmGF
# !gdown https://drive.google.com/uc?id=180ciTvm16peWrcpl4DOekT9eUQ-lJfMU
# !gdown https://drive.google.com/uc?id=1KX9MyGueFB3M-X0Ss152x_johyTXHTfU
# !gdown https://drive.google.com/uc?id=19-NyZn_I0_mkF-F5GPyFMwQJ_-WecZIL
# !gdown https://drive.google.com/uc?id=11ouQ7Wr2I-JKStp2Fd1afedmWeuifhof
# !gdown https://drive.google.com/uc?id=18ICIvQoKX-7feYWP61RbpppzDuYTptCq
# !gdown https://drive.google.com/uc?id=1VktuY46m0v_n_d4nvOupauJkK4LF6mHE
# %cd ../..

# %mkdir -p checkpoints
# %cd checkpoints
# !gdown https://drive.google.com/uc?id=1O5C1vK4yqguOhgRQ7kmYqa3-E8q5H_65
# !unzip motion2video_nerf.zip
# %mkdir audio2motion_vae
# %cd audio2motion_vae
# !gdown https://drive.google.com/uc?id=1Qg5V-1-IyEgAOxb2PbBjHpYkizuy6njf
# !gdown https://drive.google.com/uc?id=1bKY5rn3vcAkv-2m1mui0qr4Fs38jEmy-
# %cd ..

# %cd ..
# Out:
# /content/GeneFacePlusPlus/data/binary/videos/May
# Downloading...
# From: https://drive.google.com/uc?id=16fNJz5MbOMqHYHxcK_nPP4EPBXWjugR0
# To: /content/GeneFacePlusPlus/data/binary/videos/May/trainval_dataset.npy
# 100% 65.8M/65.8M [00:02<00:00, 24.6MB/s]
# /content/GeneFacePlusPlus
# /content/GeneFacePlusPlus/deep_3drecon/BFM
# Downloading...
# From (original): https://drive.google.com/uc?id=1SPM3IHsyNAaVMwqZZGV6QVaV7I2Hly0v
# From (redirected): https://drive.google.com/uc?id=1SPM3IHsyNAaVMwqZZGV6QVaV7I2Hly0v&confirm=t&uuid=9477bf37-b5e9-4572-a447-68c232db9ade
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/01_MorphableModel.mat
# 100% 241M/241M [00:09<00:00, 26.7MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1MSldX9UChKEb3AXLVTPzZQcsbGD4VmGF
# From (redirected): https://drive.google.com/uc?id=1MSldX9UChKEb3AXLVTPzZQcsbGD4VmGF&confirm=t&uuid=92e42721-6316-4017-a1ec-a5ba7a88a5bb
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/BFM_exp_idx.mat
# 100% 91.9k/91.9k [00:00<00:00, 4.44MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=180ciTvm16peWrcpl4DOekT9eUQ-lJfMU
# From (redirected): https://drive.google.com/uc?id=180ciTvm16peWrcpl4DOekT9eUQ-lJfMU&confirm=t&uuid=3d003f83-d8dd-4b2a-950d-20e4fb853357
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/BFM_front_idx.mat
# 100% 44.9k/44.9k [00:00<00:00, 60.6MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1KX9MyGueFB3M-X0Ss152x_johyTXHTfU
# From (redirected): https://drive.google.com/uc?id=1KX9MyGueFB3M-X0Ss152x_johyTXHTfU&confirm=t&uuid=1244e2dc-85de-4ec7-a185-605db39db496
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/BFM_model_front.mat
# 100% 127M/127M [00:04<00:00, 30.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=19-NyZn_I0_mkF-F5GPyFMwQJ_-WecZIL
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/Exp_Pca.bin
# 100% 51.1M/51.1M [00:03<00:00, 17.0MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=11ouQ7Wr2I-JKStp2Fd1afedmWeuifhof
# From (redirected): https://drive.google.com/uc?id=11ouQ7Wr2I-JKStp2Fd1afedmWeuifhof&confirm=t&uuid=ab991880-bc8a-4731-8189-0c2862060720
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/facemodel_info.mat
# 100% 739k/739k [00:00<00:00, 7.56MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=18ICIvQoKX-7feYWP61RbpppzDuYTptCq
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/index_mp468_from_mesh35709.npy
# 100% 3.87k/3.87k [00:00<00:00, 17.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1VktuY46m0v_n_d4nvOupauJkK4LF6mHE
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/std_exp.txt
# 100% 615/615 [00:00<00:00, 3.18MB/s]
# /content/GeneFacePlusPlus
# /content/GeneFacePlusPlus/checkpoints
# Downloading...
# From (original): https://drive.google.com/uc?id=1O5C1vK4yqguOhgRQ7kmYqa3-E8q5H_65
# From (redirected): https://drive.google.com/uc?id=1O5C1vK4yqguOhgRQ7kmYqa3-E8q5H_65&confirm=t&uuid=ab68f158-e4c6-4902-bae9-025b7a9c6635
# To: /content/GeneFacePlusPlus/checkpoints/motion2video_nerf.zip
# 100% 66.2M/66.2M [00:01<00:00, 39.4MB/s]
# Archive:  motion2video_nerf.zip
#    creating: motion2video_nerf/
#   inflating: __MACOSX/._motion2video_nerf
#   inflating: motion2video_nerf/.DS_Store
#   inflating: __MACOSX/motion2video_nerf/._.DS_Store
#    creating: motion2video_nerf/may_head/
#    creating: motion2video_nerf/may_torso/
#   inflating: motion2video_nerf/may_head/config.yaml
#   inflating: motion2video_nerf/may_head/model_ckpt_steps_250000.ckpt
#   inflating: motion2video_nerf/may_torso/config.yaml
#   inflating: motion2video_nerf/may_torso/model_ckpt_steps_250000.ckpt
# /content/GeneFacePlusPlus/checkpoints/audio2motion_vae
# Downloading...
# From: https://drive.google.com/uc?id=1Qg5V-1-IyEgAOxb2PbBjHpYkizuy6njf
# To: /content/GeneFacePlusPlus/checkpoints/audio2motion_vae/config.yaml
# 100% 1.71k/1.71k [00:00<00:00, 9.70MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1bKY5rn3vcAkv-2m1mui0qr4Fs38jEmy-
# From (redirected): https://drive.google.com/uc?id=1bKY5rn3vcAkv-2m1mui0qr4Fs38jEmy-&confirm=t&uuid=ea488f64-2067-43c7-908d-f117a3abfa4b
# To: /content/GeneFacePlusPlus/checkpoints/audio2motion_vae/model_ckpt_steps_400000.ckpt
# 100% 186M/186M [00:06<00:00, 28.1MB/s]
# /content/GeneFacePlusPlus/checkpoints
# /content/GeneFacePlusPlus

# %% [markdown]
# Inference sample

# %%
# sample inference, about 3 min
# !python inference/genefacepp_infer.py \
--a2m_ckpt=checkpoints/audio2motion_vae \
--head_ckpt= \
--torso_ckpt=checkpoints/motion2video_nerf/may_torso \
--drv_aud=data/raw/val_wavs/output.wav \
--out_name=news.mp4 \
--low_memory_usage
# Out:
# 2024-08-24 01:57:28.547867: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-24 01:57:28.815094: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-24 01:57:28.891341: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-24 01:57:29.305392: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-24 01:57:31.536374: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# | WARN: egs/egs_bases/audio2motion/vae.yaml not exist.
# | WARN: checkpoints/th1kh_512_audio2motion/base.yaml not exist.
# | Hparams:  {
#   "accumulate_grad_batches": 1,
#   "amp": false,
#   "audio_type": "hubert",
#   "base_config": [
#     "egs/egs_bases/audio2motion/vae.yaml",
#     "../th1kh_512_audio2motion/base.yaml"
#   ],
#   "batch_size": 4,
#   "binarization_args": {
#     "with_coeff": true,
#     "with_hubert": true,
#     "with_mel": true
#   },
#   "binary_data_dir": "data/binary/voxceleb2_audio2motion",
#   "blink_mode": "blink_unit",
#   "clip_grad_norm": 1,
#   "clip_grad_value": 0,
#   "debug": false,
#   "ds_name": "TH1KH_512",
#   "eval_max_batches": 10,
#   "exp_name": "",
#   "gen_dir_name": "",
#   "hidden_size": 256,
#   "infer": false,
#   "infer_audio_source_name": "",
#   "infer_ckpt_steps": 40000,
#   "infer_out_npy_name": "",
#   "init_from_ckpt": "",
#   "init_method": "tcp",
#   "lambda_kl": 0.02,
#   "lambda_kl_t1": 2000,
#   "lambda_kl_t2": 2000,
#   "lambda_l2_reg_exp": 0.1,
#   "lambda_mse_exp": 1.0,
#   "lambda_mse_lm2d": 0.0,
#   "lambda_mse_lm3d": 0.0,
#   "load_ckpt": "",
#   "load_db_to_memory": false,
#   "lr": 0.0005,
#   "max_sentences_per_batch": 512,
#   "max_tokens_per_batch": 20000,
#   "max_updates": 400000,
#   "motion_type": "exp",
#   "num_ckpt_keep": 100,
#   "num_sanity_val_steps": 5,
#   "num_valid_plots": 1,
#   "num_workers": 4,
#   "optimizer_adam_beta1": 0.9,
#   "optimizer_adam_beta2": 0.999,
#   "print_nan_grads": false,
#   "process_id": 0,
#   "raw_data_dir": "/home/tiger/datasets/raw/TH1KH_512",
#   "ref_id_mode": "first_frame",
#   "resume_from_checkpoint": 0,
#   "sample_min_length": 32,
#   "save_best": false,
#   "save_codes": [
#     "tasks",
#     "modules",
#     "egs"
#   ],
#   "save_gt": true,
#   "scheduler": "exponential",
#   "seed": 9999,
#   "smo_win_size": 5,
#   "split_seed": 999,
#   "start_rank": 0,
#   "syncnet_ckpt_dir": "checkpoints/0904_syncnet/syncnet_hubert_vox2",
#   "task_cls": "tasks.os_avatar.audio2secc_task.Audio2SECCTask",
#   "tb_log_interval": 100,
#   "total_process": 1,
#   "use_eye_amp_embed": false,
#   "use_flow": true,
#   "use_fork": true,
#   "use_kv_dataset": true,
#   "use_mouth_amp_embed": true,
#   "use_pitch": true,
#   "val_check_interval": 2000,
#   "valid_infer_interval": 2000,
#   "valid_monitor_key": "val_loss",
#   "valid_monitor_mode": "min",
#   "validate": false,
#   "warmup_updates": 1000,
#   "weight_decay": 0,
#   "work_dir": "",
#   "world_size": -1
# }
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# | load 'model' from 'checkpoints/audio2motion_vae/model_ckpt_steps_400000.ckpt', strict=True
# | WARN: checkpoints/motion2video_nerf/may_torso/lm3d_radnerf_torso.yaml not exist.
# | load 'model' from 'checkpoints/motion2video_nerf/may_torso/model_ckpt_steps_250000.ckpt', strict=True
# trainval: Smooth head trajectory (rotation and translation) with a window size of 7
# /content/GeneFacePlusPlus/./tasks/radnerfs/dataset_utils.py:266: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.lm68s = torch.tensor(self.lm2ds[:, index_lm68_from_lm478, :])
# /content/GeneFacePlusPlus/inference/genefacepp_infer.py:184: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   eye_area_percents = torch.tensor(self.dataset.eye_area_percents)
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Extracted wav file (16khz) from data/raw/val_wavs/output.wav to data/raw/val_wavs/output_16k.wav.
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# Loading the HuBERT Model...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 1.38k/1.38k [00:00<00:00, 9.35MB/s]
# pytorch_model.bin: 100% 1.26G/1.26G [00:06<00:00, 197MB/s]
# Some weights of HubertModel were not initialized from the model checkpoint at facebook/hubert-large-ls960-ft and are newly initialized: ['hubert.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'hubert.encoder.pos_conv_embed.conv.parametrizations.weight.original0']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading the Wav2Vec2 Processor...
# preprocessor_config.json: 100% 212/212 [00:00<00:00, 1.30MB/s]
# tokenizer_config.json: 100% 138/138 [00:00<00:00, 1.06MB/s]
# vocab.json: 100% 291/291 [00:00<00:00, 1.98MB/s]
# special_tokens_map.json: 100% 85.0/85.0 [00:00<00:00, 495kB/s]
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# GeneFace++ is rendering... :   0% 0/2088 [00:00<?, ?it/s]Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# GeneFace++ is rendering... : 100% 2088/2088 [03:45<00:00,  9.26it/s]
# Saved at news.mp4

# %% [markdown]
# Display output video

# %%
# borrow code from makeittalk
from IPython.display import HTML
from base64 import b64encode
import os, sys
import glob

mp4_name = './news.mp4'

mp4 = open('{}'.format(mp4_name),'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

print('Display animation: {}'.format(mp4_name), file=sys.stderr)
display(HTML("""
  <video width=256 controls>
        <source src="%s" type="video/mp4">
  </video>
  """ % data_url))
